# %%
import pandas as pd

# %%
compras = pd.read_csv('VendasGrano_csv.csv', encoding='latin1', delimiter=';')

# %%
print(compras.columns)
# Out:
# Index(['Data de Emissão', 'Data de Lançamento', 'Fornecedor',
#        'Descrição Material', 'Qtde.', 'Unidade', 'Preço Unitário (R$)',
#        'Acréscimo (R$)', 'Desconto (R$)', 'Total (R$)', 'Grupo do Material'],
#       dtype='object')

# %%
empresas_fornecedores = compras['Fornecedor'].drop_duplicates()
print(empresas_fornecedores)
# Out:
# 0                         UMEHARA ALIMENTOS LTDA
# 11      REZENDE E KONCIKOSKI COMERCIO ATACADISTA
# 16        RIO QUALITY COMERCIO DE ALIMENTOS LTDA
# 17             CDI BARRA PRODUTOS IMP E EXP LTDA
# 18           Supermercados unidos (pai da luiza)
#                           ...
# 6403                      MRX DISTRIBUIDORA LTDA
# 7321                50.403.876 BRUNO BRAGA NUNES
# 7722       RIO VERDE EQUIP COM E MANUTENCAO LTDA
# 7732                BARRA JALC VESTUARIO LTDA ME
# 8087                 ATACADISTA PUGLIE LTDA - ME
# Name: Fornecedor, Length: 176, dtype: object

# %%
frequencia_fornecedores = compras['Fornecedor'].value_counts()
print(frequencia_fornecedores)
# Out:
# Fornecedor
# UMEHARA ALIMENTOS LTDA                      1282
# Hortifruti Genesis Ltda                      943
# Supermercados unidos (pai da luiza)          876
# RIO QUALITY COMERCIO DE ALIMENTOS LTDA       427
# Coca cola                                    307
#                                             ...
# DAMM PRODUTOS ALIMENTICIOS LTDA                1
# MG SUPREME DISTRIBUIDORA DE ALIMENTOS EI       1
# REBELA COMERCIAL EXPORTADORA LTDA              1
# 50.403.876 BRUNO BRAGA NUNES                   1
# RIO VERDE EQUIP COM E MANUTENCAO LTDA          1
# Name: count, Length: 175, dtype: int64

# %%
produtos_umehara = compras[compras['Fornecedor'] == 'UMEHARA ALIMENTOS LTDA']['Descrição Material'].unique()
print(produtos_umehara)
# Out:
# ['Abobrinha italiana' 'Aneto / dill' 'Manjericao' 'Ovo Branco Extra'
#  'Batata baroa' 'Beterraba' 'Cenoura' 'Tomate salada' 'Manga'
#  'Mamao Formosa' 'Uva verde thompson' 'Melao Amarelo ' 'Banana prata'
#  'Mamao papaya ' 'Laranja ' 'Banana Dgua' 'Limao taiti' 'Maca verde'
#  'Tomate cereja' 'Cebola roxa' 'Rucula' 'Salvia' 'Alho descascado'
#  'Couve manteiga' 'Hortela' 'Batata calabresa' 'Vagem francesa' 'Abacate'
#  'Morango' 'Melancia ' 'Limao siciliano' 'Berinjela' 'Coentro' 'Abacaxi'
#  'Pepino japones' 'Batata asterix' 'Couve flor' 'Alecrim' 'Mandioca'
#  'Cebola calabresa ech' 'Maca gala' 'Kiwi' 'Repolho roxo'
#  'Pimentao amarelo' 'Pimentao vermelho' 'Framboesa' 'Batata inglesa'
#  'Batata doce ' 'Cebolinha' 'Brocolis americano' 'Salsa lisa' 'Maracuja'
#  'Cebola branca' 'Pimentao verde' 'Pimenta dedo de moca' 'Tomilho'
#  'Alho poro' 'Aipo' 'Oregano' 'Chuchu' 'Ovo de codorna conse'
#  'Abobora sergipana' 'Pera' 'Pepino' 'Gengibre' 'Tomate molho' 'Brocolis'
#  'Rabanete']

# %%
produtos_hortifruti_genesis = compras[compras['Fornecedor'] == 'Hortifruti Genesis Ltda']['Descrição Material'].unique()
print(produtos_hortifruti_genesis)
# Out:
# ['Pimentao amarelo' 'Pimentao verde' 'Pimentao vermelho' 'Hortela'
#  'Couve flor' 'Brocolis americano' 'Salsa lisa' 'Alho poro'
#  'Alface americana' 'Alface crespa' 'Abobrinha italiana' 'Rucula'
#  'Coentro' 'Batata asterix' 'Berinjela' 'Beterraba' 'Chuchu'
#  'Pepino japones' 'Limao taiti' 'Tomate salada' 'Abacaxi' 'Melancia '
#  'Abacate' 'Tomate cereja' 'Mandioca' 'Agriao' 'Manjericao' 'Louro'
#  'Abobora sergipana' 'Aipo' 'Alface crespa roxa' 'Pepino' 'Cenoura'
#  'Cebola branca' 'Batata baroa' 'Banana prata' 'Pera' 'Couve manteiga'
#  'Tomate molho' 'Brocolis' 'Laranja ' 'Batata inglesa' 'Cebola roxa'
#  'Maca gala' 'Vagem francesa' 'Batata calabresa' 'Repolho verde'
#  'Rabanete' 'Aneto / dill' 'Morango' 'Alecrim' 'Salvia' 'Tomilho'
#  'Banana Dgua' 'Mamao papaya ' 'Cebolinha' 'Cebola calabresa ech'
#  'Maracuja' 'Batata doce ' 'Ovo Branco Extra' 'Oregano'
#  'Uva verde thompson']

# %%
produtos_unidos = compras[compras['Fornecedor'] == 'Supermercados unidos (pai da luiza)']['Descrição Material'].unique()
print(produtos_unidos)
# Out:
# ['Leite Int Elege' 'Granola crocante pro' 'Requeijao elege trad'
#  'Carne Moida' 'Queijo Mussarela Pro' 'Queijo ralado president'
#  'Pipoca Yoki mic sabores' 'Drumet de frango' 'Goiabada bloco'
#  'Peito de frango' 'Feijao mulatinho' 'Grao de bico'
#  'biscoito Maizena Pro' 'Acem' 'Milho lata' 'Feijao vermelho'
#  'Acucar refinado' 'atum solido 170g' 'Nutella 140g'
#  'Acucar Refinado uniao 1kg' 'Requei lgtelege 200g' 'manteiga itambe 200g'
#  'toddynho 200ml' 'Arroz branco' 'Arroz integral' 'Feijao preto'
#  'Feijao branco' 'Lentilha' 'Farin mand crua' 'Azeite oliva andorin'
#  'Massa espaguete' 'Sal refinado' 'Carne seca' 'Leite em po'
#  'Vinagre balsamico' 'Conhaque cozinha' 'acucar demerara unia'
#  'Arroz Parborizado' 'Iogurte Natural 170g' 'Iogurte Desnat 160g'
#  'Iogurte Neston 170g' 'Iogurte Maca Banana ' 'cafe pilao 500g'
#  'Queijo Ricota Fresca' 'Nescafe Tradic' 'manteiga pres c sal 200g'
#  'Cabeça fritadores' 'Batata palha' 'File Coxa e Sobrecox'
#  'Nescau 2.0 200g' 'Manteiga eleg c/ sal' 'Coca Cola 2l'
#  'schweppes tonic lata' 'Abacate' 'Coca Cola Lata' 'Leite desnata Elege'
#  'Sal grosso' 'Acucar Glacucar' 'Mostarda escura' 'Costela bovina'
#  'Carre Suino Cong' 'orelha' 'rabo suino' 'Leite elege semi desnatado'
#  'cerv heineken long neck' 'Leite Italac 1L' 'Coqueteleira' 'Rabada'
#  'Frango inteiro' 'Vina bran maca' 'Alho descascado' 'Linguica calabresa'
#  'Lombo suino Salgado' 'Oleo soja' 'cappuc clasc 3 cor'
#  'Acucar uniao 5g Orga' 'Lagarto redondo' 'Figado de galinha'
#  'Zero cal stevia 80 ml' 'Cappuccino 3 coracoes diet ' 'Cenoura'
#  'Batata inglesa' 'Ovos pasteurizados' 'Tomate salada' 'Aveia flocos fina'
#  'Leite de coco' 'Peito de Peru Sadia' 'leite po ninho 380g'
#  'Azeitona Preta Azapa' 'Presunto alemao' 'Leite Itambe Zero Lac Integral'
#  'Cerv Amer Prem Lager' 'Maionese Hellmanns 500g' 'File de Fgo Sassami'
#  'Lamina p/ estilete p' 'Batata palha elma chips trad' 'Laranja '
#  'Coxao mole bovino' 'Banana Dgua' 'Pepino' 'Limao taiti' 'Cebola roxa'
#  'Beterraba' 'Cebola branca' 'Mandioca' 'Chuchu' 'Berinjela'
#  'Batata calabresa' 'Azeitona verde ' 'Mostarda heinz yellow 255g'
#  'Feijao carioca' 'Farinha de trigo' 'Abobrinha italiana' 'Banana prata'
#  'Batata doce ' 'Cafe em po funci' 'leite cond moca 395g'
#  'Mant president 250g' 'Manteiga pote s/sal president'
#  'Creme de ricota president 200g' 'Coca cola zero 2l'
#  'Coca cola zero 600ml' 'Maca gala' 'Leite integral Produ'
#  'DEL VALLE LARANJA' 'manteiga s/sal presidente tabl' 'Del valle sabores'
#  'Batata asterix' 'Vinagre de maca' 'Red bull 250ml'
#  ' red bull sem açucar 250ml' 'Ketchup bac e ceb heinz' 'File Mingnon'
#  'sapolio' 'Creme de leite' 'Bucho Bovino' 'Maracuja' 'Fanta laranja 2l'
#  'Fanta uva 2l' 'Nescafe original 40g' 'Melao Amarelo '
#  'Filtro de papel melitta Origin']

# %%
def imprimir_informacoes(compras, item):
    print('Mercadoria:', item)

    item_compras = compras[compras['Descrição Material'] == item]

    preco_unitario_por_fornecedor = {}
    valor_total_por_fornecedor = {}
    quantidade_por_fornecedor = {}

    for index, row in item_compras.iterrows():
        fornecedor = row['Fornecedor']
        preco_unitario = float(row['Preço Unitário (R$)'].replace(',', '.'))
        quantidade = float(row['Qtde.'].replace(',', '.'))
        valor_total = row['Total (R$)']

        if isinstance(valor_total, float):
            valor_total = str(valor_total)

        valor_total = float(valor_total.replace(',', '.'))

        if fornecedor in preco_unitario_por_fornecedor:
            preco_unitario_por_fornecedor[fornecedor] += preco_unitario * quantidade
            valor_total_por_fornecedor[fornecedor] += valor_total
            quantidade_por_fornecedor[fornecedor] += quantidade
        else:
            preco_unitario_por_fornecedor[fornecedor] = preco_unitario * quantidade
            valor_total_por_fornecedor[fornecedor] = valor_total
            quantidade_por_fornecedor[fornecedor] = quantidade

    for fornecedor in preco_unitario_por_fornecedor.keys():
        preco_unitario = preco_unitario_por_fornecedor[fornecedor] / quantidade_por_fornecedor[fornecedor]
        valor_total = valor_total_por_fornecedor[fornecedor]
        quantidade = quantidade_por_fornecedor[fornecedor]
        print('\n')
        print(f'Fornecedor: {fornecedor}')
        print(f'  Preço Unitário(R$): {preco_unitario:.2f}')
        print(f'  Valor Total(R$): {valor_total:.2f}')
        print(f'  Quantidade: {quantidade}')
    print()

top_fornecedores = ['UMEHARA ALIMENTOS LTDA', 'Hortifruti Genesis Ltda', 'Supermercados unidos (pai da luiza)']
itens_comuns = encontrar_itens_semelhantes(compras, top_fornecedores)

for item in itens_comuns:
    imprimir_informacoes(compras, item)
# Out:
# Mercadoria: Abobrinha italiana
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 4.41
#   Valor Total(R$): 528.82
#   Quantidade: 120.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 5.58
#   Valor Total(R$): 942.40
#   Quantidade: 169.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 4.49
#   Valor Total(R$): 1036.50
#   Quantidade: 231.0
#
# Mercadoria: Beterraba
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 6.16
#   Valor Total(R$): 369.85
#   Quantidade: 60.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 3.55
#   Valor Total(R$): 124.38
#   Quantidade: 35.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 6.33
#   Valor Total(R$): 436.97
#   Quantidade: 69.0
#
# Mercadoria: Cenoura
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 7.66
#   Valor Total(R$): 2359.10
#   Quantidade: 308.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 8.51
#   Valor Total(R$): 297.95
#   Quantidade: 35.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 8.48
#   Valor Total(R$): 2398.68
#   Quantidade: 283.0
#
# Mercadoria: Tomate salada
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 9.61
#   Valor Total(R$): 3259.18
#   Quantidade: 339.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 8.28
#   Valor Total(R$): 563.34
#   Quantidade: 68.0
#
#
# Fornecedor: nan
#   Preço Unitário(R$): 7.99
#   Valor Total(R$): 23.97
#   Quantidade: 3.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 6.75
#   Valor Total(R$): 1040.18
#   Quantidade: 154.0
#
# Mercadoria: Banana prata
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 9.37
#   Valor Total(R$): 299.72
#   Quantidade: 32.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 15.00
#   Valor Total(R$): 120.00
#   Quantidade: 8.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 8.57
#   Valor Total(R$): 165.34
#   Quantidade: 19.28
#
# Mercadoria: Laranja
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 56.10
#   Valor Total(R$): 33770.00
#   Quantidade: 602.0
#
#
# Fornecedor: nan
#   Preço Unitário(R$): 54.00
#   Valor Total(R$): 1134.00
#   Quantidade: 21.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 61.33
#   Valor Total(R$): 368.00
#   Quantidade: 6.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 52.93
#   Valor Total(R$): 370.53
#   Quantidade: 7.0
#
# Mercadoria: Banana Dgua
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 5.99
#   Valor Total(R$): 329.48
#   Quantidade: 55.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 11.50
#   Valor Total(R$): 69.00
#   Quantidade: 6.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 3.71
#   Valor Total(R$): 204.10
#   Quantidade: 55.0
#
# Mercadoria: Limao taiti
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 2.63
#   Valor Total(R$): 376.75
#   Quantidade: 143.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 3.99
#   Valor Total(R$): 55.86
#   Quantidade: 14.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 2.82
#   Valor Total(R$): 386.69
#   Quantidade: 137.0
#
# Mercadoria: Cebola roxa
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 8.33
#   Valor Total(R$): 532.86
#   Quantidade: 64.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 8.54
#   Valor Total(R$): 42.68
#   Quantidade: 5.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 8.86
#   Valor Total(R$): 390.00
#   Quantidade: 44.0
#
# Mercadoria: Batata asterix
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 8.26
#   Valor Total(R$): 1363.56
#   Quantidade: 165.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 13.03
#   Valor Total(R$): 1954.82
#   Quantidade: 150.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 143.82
#   Valor Total(R$): 143.82
#   Quantidade: 1.0
#
# Mercadoria: Batata calabresa
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 6.67
#   Valor Total(R$): 586.75
#   Quantidade: 88.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 6.31
#   Valor Total(R$): 315.50
#   Quantidade: 50.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 4.17
#   Valor Total(R$): 41.67
#   Quantidade: 10.0
#
# Mercadoria: Berinjela
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 4.68
#   Valor Total(R$): 477.17
#   Quantidade: 102.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 4.38
#   Valor Total(R$): 376.75
#   Quantidade: 86.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 4.34
#   Valor Total(R$): 423.87
#   Quantidade: 97.57
#
# Mercadoria: Chuchu
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 5.26
#   Valor Total(R$): 110.50
#   Quantidade: 21.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 6.40
#   Valor Total(R$): 102.44
#   Quantidade: 16.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 2.53
#   Valor Total(R$): 103.61
#   Quantidade: 41.0
#
# Mercadoria: Abacate
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 6.89
#   Valor Total(R$): 117.12
#   Quantidade: 17.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 7.00
#   Valor Total(R$): 189.00
#   Quantidade: 27.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 4.41
#   Valor Total(R$): 166.72
#   Quantidade: 37.83
#
# Mercadoria: Mandioca
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 3.99
#   Valor Total(R$): 239.40
#   Quantidade: 60.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 3.16
#   Valor Total(R$): 192.59
#   Quantidade: 61.0
#
#
# Fornecedor: RIO QUALITY COMERCIO DE ALIMENTOS LTDA
#   Preço Unitário(R$): 33.61
#   Valor Total(R$): 941.04
#   Quantidade: 28.0
#
#
# Fornecedor: TOP ALTO PARTICIPACOES E COMERCIO LTDA
#   Preço Unitário(R$): 13.88
#   Valor Total(R$): 277.60
#   Quantidade: 20.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 2.41
#   Valor Total(R$): 303.18
#   Quantidade: 126.0
#
#
# Fornecedor: FRIGORIFICO IRMAOS SOUSA COMERCIO DE ALI
#   Preço Unitário(R$): 11.50
#   Valor Total(R$): 230.00
#   Quantidade: 20.0
#
# Mercadoria: Pepino
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 4.50
#   Valor Total(R$): 18.00
#   Quantidade: 4.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 3.40
#   Valor Total(R$): 6.80
#   Quantidade: 2.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 3.37
#   Valor Total(R$): 20.22
#   Quantidade: 6.0
#
# Mercadoria: Cebola branca
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 11.42
#   Valor Total(R$): 479.80
#   Quantidade: 42.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 6.54
#   Valor Total(R$): 503.25
#   Quantidade: 77.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 127.36
#   Valor Total(R$): 1401.00
#   Quantidade: 11.0
#
# Mercadoria: Maca gala
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 11.30
#   Valor Total(R$): 282.50
#   Quantidade: 25.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 8.00
#   Valor Total(R$): 239.90
#   Quantidade: 30.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 9.20
#   Valor Total(R$): 404.73
#   Quantidade: 44.0
#
# Mercadoria: Batata inglesa
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 7.52
#   Valor Total(R$): 676.80
#   Quantidade: 90.0
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 10.79
#   Valor Total(R$): 2437.45
#   Quantidade: 226.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 12.76
#   Valor Total(R$): 2270.40
#   Quantidade: 178.0
#
# Mercadoria: Batata doce
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 5.83
#   Valor Total(R$): 186.43
#   Quantidade: 32.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 3.50
#   Valor Total(R$): 21.00
#   Quantidade: 6.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 3.79
#   Valor Total(R$): 109.88
#   Quantidade: 29.0
#
# Mercadoria: Maracuja
#
#
# Fornecedor: UMEHARA ALIMENTOS LTDA
#   Preço Unitário(R$): 15.70
#   Valor Total(R$): 188.40
#   Quantidade: 12.0
#
#
# Fornecedor: Hortifruti Genesis Ltda
#   Preço Unitário(R$): 16.00
#   Valor Total(R$): 64.00
#   Quantidade: 4.0
#
#
# Fornecedor: Supermercados unidos (pai da luiza)
#   Preço Unitário(R$): 8.00
#   Valor Total(R$): 8.00
#   Quantidade: 1.0
